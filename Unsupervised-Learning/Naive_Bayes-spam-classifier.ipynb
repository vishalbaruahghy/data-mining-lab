# %% [markdown]
# # Naive-Baye's Spam and Ham Email Classifier

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ## Loading the Downloaded Dataset

# %%
url = '../downloads/SMSSpamCollection' # Downloaded and extracted from UCI repository
data = pd.read_csv(url, sep='\t', header=None, names=['label', 'message'])

# %%
# Inspect the first few rows
data.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Split the dataset into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data['message'], data['label'], test_size=0.2, random_state=42
)

# %% [markdown]
# ## Convert the text into a matrix of token counts

# %%
vectorizer = CountVectorizer(stop_words='english')
X_train_vectorized = vectorizer.fit_transform(X_train)
X_test_vectorized = vectorizer.transform(X_test)

# %% [markdown]
# ## Initialize and train the Naive Bayes classifier

# %%
nb_model = MultinomialNB()
nb_model.fit(X_train_vectorized, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# ## Predict and Analyze the trained Model

# %%
y_pred = nb_model.predict(X_test_vectorized)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9883408071748879
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          ham       0.99      0.99      0.99       966
#         spam       0.97      0.95      0.96       149
#
#     accuracy                           0.99      1115
#    macro avg       0.98      0.97      0.97      1115
# weighted avg       0.99      0.99      0.99      1115

# %% [markdown]
# ## Example Outputs

# %%
# New unseen message
new_messages = ["Congratulations! You've won a Rs 1000 gift card.", 
                "Hey, are we still meeting tomorrow?"]

# Vectorize new messages
new_messages_vectorized = vectorizer.transform(new_messages)

# Predict
predictions = nb_model.predict(new_messages_vectorized)

print("Predictions:", predictions)  # Output will be 'spam' or 'ham'
# Out:
# Predictions: ['spam' 'ham']
